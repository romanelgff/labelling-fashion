# %%
import io
import itertools

import numpy as np
import sklearn.metrics

import tensorflow as tf
from tensorboard.plugins.hparams import api as hp

import matplotlib.pyplot as plt

# %%
# Loading the datasets
data_train = np.load(r"Dataset/Trousers & Jeans - All - Train.npz")
data_val = np.load(r"Dataset/Trousers & Jeans - All - Validation.npz")
data_test = np.load(r"Dataset/Trousers & Jeans - All - Test.npz")

# %%
# Extracting the arrays from the imported data
images_train = data_train['images']
labels_train = data_train['labels']

images_val = data_val['images']
labels_val = data_val['labels']

images_test = data_test['images']
labels_test = data_test['labels']

# %%
# Scaling the pixel values of all images 
images_train = images_train/255.0
images_val = images_val/255.0
images_test = images_test/255.0

# %%
# Defining the hyperparameters we would tune, and their values to be tested
HP_FILTER_SIZE_1 = hp.HParam('filter_size_1', hp.Discrete([3,5,7]))
HP_FILTER_NUM = hp.HParam('filters_number', hp.Discrete([32,64,96,128]))
HP_FILTER_SIZE_2 = hp.HParam('filter_size_2', hp.Discrete([3,5]))

METRIC_ACCURACY = 'accuracy'

# Logging setup info
with tf.summary.create_file_writer(r'Logs/Model 2/hparam_tuning/').as_default():
    hp.hparams_config(
        hparams=[HP_FILTER_SIZE_1, HP_FILTER_NUM, HP_FILTER_SIZE_2],
        metrics=[hp.Metric(METRIC_ACCURACY, display_name='Accuracy')],
    )

# %%
EPOCHS = 20
BATCH_SIZE = 64

# %%
# Wrapping our model and training in a function
def train_test_model(hparams, session_num):
    
    # Outlining the model/architecture of our CNN
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(hparams[HP_FILTER_NUM], hparams[HP_FILTER_SIZE_1], activation='relu', input_shape=(120,90,3)),
        tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
        tf.keras.layers.Conv2D(hparams[HP_FILTER_NUM], hparams[HP_FILTER_SIZE_2], activation='relu'),
        tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(4)
    ])
    
    # Defining the loss function
    loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

    # Compiling the model
    model.compile(optimizer='adam', loss=loss_fn, metrics=['accuracy'])

    # Defining the logging directory
    log_dir = "Logs/Model 2/fit/" + "run-{}".format(session_num)
    
    def plot_confusion_matrix(cm, class_names):
        """
        Returns a matplotlib figure containing the plotted confusion matrix.

        Args:
          cm (array, shape = [n, n]): a confusion matrix of integer classes
          class_names (array, shape = [n]): String names of the integer classes
        """
        figure = plt.figure(figsize=(12, 12))
        plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
        plt.title("Confusion matrix")
        plt.colorbar()
        tick_marks = np.arange(len(class_names))
        plt.xticks(tick_marks, class_names, rotation=45)
        plt.yticks(tick_marks, class_names)

        # Normalize the confusion matrix.
        cm = np.around(cm.astype('float') / cm.sum(axis=1)[:, np.newaxis], decimals=2)

        # Use white text if squares are dark; otherwise black.
        threshold = cm.max() / 2.
        for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
            color = "white" if cm[i, j] > threshold else "black"
            plt.text(j, i, cm[i, j], horizontalalignment="center", color=color)

        plt.tight_layout()
        plt.ylabel('True label')
        plt.xlabel('Predicted label')
        return figure 
    
    
    def plot_to_image(figure):
        """Converts the matplotlib plot specified by 'figure' to a PNG image and
        returns it. The supplied figure is closed and inaccessible after this call."""
        # Save the plot to a PNG in memory.
        buf = io.BytesIO()
        plt.savefig(buf, format='png')
        # Closing the figure prevents it from being displayed directly inside
        # the notebook.
        plt.close(figure)
        buf.seek(0)
        # Convert PNG buffer to TF image
        image = tf.image.decode_png(buf.getvalue(), channels=4)
        # Add the batch dimension
        image = tf.expand_dims(image, 0)
        return image
    
    
    
    # Defining a file writer for Confusion Matrix logging purposes
    file_writer_cm = tf.summary.create_file_writer(log_dir + '/cm')
    
    
    
    def log_confusion_matrix(epoch, logs):
        # Use the model to predict the values from the validation dataset.
        test_pred_raw = model.predict(images_val)
        test_pred = np.argmax(test_pred_raw, axis=1)

        # Calculate the confusion matrix.
        cm = sklearn.metrics.confusion_matrix(labels_val, test_pred)
        # Log the confusion matrix as an image summary.
        figure = plot_confusion_matrix(cm, class_names=['Trousers Male', 'Jeans Male', 'Trousers Female', "Jeans Female"])
        cm_image = plot_to_image(figure)

        # Log the confusion matrix as an image summary.
        with file_writer_cm.as_default():
            tf.summary.image("Confusion Matrix", cm_image, step=epoch)
    
    
    # Define the Tensorboard and Confusion Matrix callbacks.
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1, profile_batch=0)
    cm_callback = tf.keras.callbacks.LambdaCallback(on_epoch_end=log_confusion_matrix)

    
    # Defining early stopping to prevent overfitting
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor = 'val_loss',
        mode = 'auto',
        min_delta = 0,
        patience = 2,
        verbose = 0, 
        restore_best_weights = True
    )
    
    # Training the model
    model.fit(
        images_train,
        labels_train,
        epochs = EPOCHS,
        batch_size = BATCH_SIZE,
        callbacks = [tensorboard_callback, cm_callback, early_stopping],
        validation_data = (images_val,labels_val),
        verbose = 2
    )
    
    # Evaluating the model's performance on the validation set
    _, accuracy = model.evaluate(images_val,labels_val)
    
    # Saving the current model for future reference
    model.save(r"saved_models/Model 2/Run-{}".format(session_num))
    
    return accuracy

# %%
# Creating a function to log the resuls
def run(log_dir, hparams, session_num):
    
    with tf.summary.create_file_writer(log_dir).as_default():
        hp.hparams(hparams)  # record the values used in this trial
        accuracy = train_test_model(hparams, session_num)
        tf.summary.scalar(METRIC_ACCURACY, accuracy, step=1)

# %%
session_num = 1

for filter_size_1 in HP_FILTER_SIZE_1.domain.values:
    for filter_num in HP_FILTER_NUM.domain.values:
        for filter_size_2 in HP_FILTER_SIZE_2.domain.values:

            hparams = {
                HP_FILTER_SIZE_1: filter_size_1,
                HP_FILTER_NUM: filter_num,
                HP_FILTER_SIZE_2: filter_size_2
            }

            run_name = "run-%d" % session_num
            print('--- Starting trial: %s' % run_name)
            print({h.name: hparams[h] for h in hparams})
            run('Logs/Model 2/hparam_tuning/' + run_name, hparams, session_num)

            session_num += 1
# Out:
# --- Starting trial: run-1
# {'filter_size_1': 3, 'filters_number': 32, 'filter_size_2': 3}
# Epoch 1/20
# 63/63 - 31s - loss: 1.1792 - accuracy: 0.4833 - val_loss: 1.0554 - val_accuracy: 0.5540
# Epoch 2/20
# 63/63 - 31s - loss: 0.8927 - accuracy: 0.6379 - val_loss: 0.9067 - val_accuracy: 0.6400
# Epoch 3/20
# 63/63 - 34s - loss: 0.7886 - accuracy: 0.6836 - val_loss: 0.8695 - val_accuracy: 0.6220
# Epoch 4/20
# 63/63 - 32s - loss: 0.7532 - accuracy: 0.6948 - val_loss: 0.8337 - val_accuracy: 0.6780
# Epoch 5/20
# 63/63 - 31s - loss: 0.6856 - accuracy: 0.7350 - val_loss: 0.7774 - val_accuracy: 0.6960
# Epoch 6/20
# 63/63 - 35s - loss: 0.6458 - accuracy: 0.7510 - val_loss: 0.8208 - val_accuracy: 0.7160
# Epoch 7/20
# 63/63 - 36s - loss: 0.6518 - accuracy: 0.7428 - val_loss: 0.8987 - val_accuracy: 0.6420
# 16/16 [==============================] - 1s 83ms/step - loss: 0.7774 - accuracy: 0.6960
# INFO:tensorflow:Assets written to: saved_models/Model 2/Run-1/assets
# --- Starting trial: run-2
# {'filter_size_1': 3, 'filters_number': 32, 'filter_size_2': 5}
# Epoch 1/20
# 63/63 - 64s - loss: 1.1612 - accuracy: 0.4955 - val_loss: 1.0488 - val_accuracy: 0.5580
# Epoch 2/20
# 63/63 - 59s - loss: 0.9165 - accuracy: 0.6286 - val_loss: 0.9916 - val_accuracy: 0.6120
# Epoch 3/20
# 63/63 - 65s - loss: 0.8293 - accuracy: 0.6591 - val_loss: 0.8707 - val_accuracy: 0.6720
# Epoch 4/20
# 63/63 - 56s - loss: 0.7737 - accuracy: 0.6933 - val_loss: 0.8864 - val_accuracy: 0.6420
# Epoch 5/20
# 63/63 - 53s - loss: 0.7314 - accuracy: 0.7013 - val_loss: 0.9394 - val_accuracy: 0.6060
# 16/16 [==============================] - 1s 77ms/step - loss: 0.8707 - accuracy: 0.6720
# INFO:tensorflow:Assets written to: saved_models/Model 2/Run-2/assets
# --- Starting trial: run-3
# {'filter_size_1': 3, 'filters_number': 64, 'filter_size_2': 3}
# Epoch 1/20
# 63/63 - 82s - loss: 1.1275 - accuracy: 0.5130 - val_loss: 1.0191 - val_accuracy: 0.5900
# Epoch 2/20
# 63/63 - 77s - loss: 0.8621 - accuracy: 0.6471 - val_loss: 0.9071 - val_accuracy: 0.6600
# Epoch 3/20
# 63/63 - 104s - loss: 0.7627 - accuracy: 0.6938 - val_loss: 0.8670 - val_accuracy: 0.6440
# Epoch 4/20
# 63/63 - 85s - loss: 0.7088 - accuracy: 0.7155 - val_loss: 0.8261 - val_accuracy: 0.6480
# Epoch 5/20
# 63/63 - 72s - loss: 0.6493 - accuracy: 0.7425 - val_loss: 0.8058 - val_accuracy: 0.6620
# Epoch 6/20
# 63/63 - 74s - loss: 0.5945 - accuracy: 0.7667 - val_loss: 0.7644 - val_accuracy: 0.7140
# Epoch 7/20
# 63/63 - 72s - loss: 0.5829 - accuracy: 0.7767 - val_loss: 0.7784 - val_accuracy: 0.7020
# Epoch 8/20
# 63/63 - 78s - loss: 0.5313 - accuracy: 0.7990 - val_loss: 0.8084 - val_accuracy: 0.6920
# 16/16 [==============================] - 2s 115ms/step - loss: 0.7644 - accuracy: 0.7140
# INFO:tensorflow:Assets written to: saved_models/Model 2/Run-3/assets
# --- Starting trial: run-4
# {'filter_size_1': 3, 'filters_number': 64, 'filter_size_2': 5}
# Epoch 1/20
# 63/63 - 100s - loss: 1.2554 - accuracy: 0.4568 - val_loss: 1.1072 - val_accuracy: 0.5180
# Epoch 2/20
# 63/63 - 98s - loss: 0.9345 - accuracy: 0.6224 - val_loss: 0.9857 - val_accuracy: 0.6000
# Epoch 3/20
# 63/63 - 99s - loss: 0.8653 - accuracy: 0.6508 - val_loss: 0.9735 - val_accuracy: 0.5640
# Epoch 4/20
# 63/63 - 98s - loss: 0.8086 - accuracy: 0.6711 - val_loss: 0.9269 - val_accuracy: 0.6160
# Epoch 5/20
# 63/63 - 97s - loss: 0.7630 - accuracy: 0.6911 - val_loss: 0.8844 - val_accuracy: 0.6360
# Epoch 6/20
# 63/63 - 98s - loss: 0.7126 - accuracy: 0.7160 - val_loss: 0.9017 - val_accuracy: 0.6340
# Epoch 7/20
# 63/63 - 1900s - loss: 0.6849 - accuracy: 0.7315 - val_loss: 0.8558 - val_accuracy: 0.6520
# Epoch 8/20
# 63/63 - 113s - loss: 0.6732 - accuracy: 0.7278 - val_loss: 0.8333 - val_accuracy: 0.6580
# Epoch 9/20
# 63/63 - 122s - loss: 0.6513 - accuracy: 0.7385 - val_loss: 0.8208 - val_accuracy: 0.6980
# Epoch 10/20
# 63/63 - 123s - loss: 0.6275 - accuracy: 0.7525 - val_loss: 0.8003 - val_accuracy: 0.6820
# Epoch 11/20
# 63/63 - 124s - loss: 0.5968 - accuracy: 0.7612 - val_loss: 0.7587 - val_accuracy: 0.7080
# Epoch 12/20
# 63/63 - 126s - loss: 0.5658 - accuracy: 0.7847 - val_loss: 0.8161 - val_accuracy: 0.6860
# Epoch 13/20
# 63/63 - 1050s - loss: 0.5439 - accuracy: 0.7895 - val_loss: 0.7737 - val_accuracy: 0.7280
# 16/16 [==============================] - 3s 182ms/step - loss: 0.7587 - accuracy: 0.7080
# INFO:tensorflow:Assets written to: saved_models/Model 2/Run-4/assets
# --- Starting trial: run-5
# {'filter_size_1': 3, 'filters_number': 96, 'filter_size_2': 3}
# Epoch 1/20
# 63/63 - 115s - loss: 1.1294 - accuracy: 0.5160 - val_loss: 0.9834 - val_accuracy: 0.5980
# Epoch 2/20
# 63/63 - 123s - loss: 0.8566 - accuracy: 0.6508 - val_loss: 0.9199 - val_accuracy: 0.6060
# Epoch 3/20
# 63/63 - 132s - loss: 0.7420 - accuracy: 0.7053 - val_loss: 0.9008 - val_accuracy: 0.6200
# Epoch 4/20
# 63/63 - 132s - loss: 0.6867 - accuracy: 0.7268 - val_loss: 0.7986 - val_accuracy: 0.6800
# Epoch 5/20
# 63/63 - 134s - loss: 0.6231 - accuracy: 0.7610 - val_loss: 0.7985 - val_accuracy: 0.6700
# Epoch 6/20
# 63/63 - 133s - loss: 0.5422 - accuracy: 0.7882 - val_loss: 0.7323 - val_accuracy: 0.7300
# Epoch 7/20
# 63/63 - 133s - loss: 0.5486 - accuracy: 0.7930 - val_loss: 0.7485 - val_accuracy: 0.7080
# Epoch 8/20
# 63/63 - 135s - loss: 0.4883 - accuracy: 0.8152 - val_loss: 0.7870 - val_accuracy: 0.7480
# 16/16 [==============================] - 4s 257ms/step - loss: 0.7323 - accuracy: 0.7300
# INFO:tensorflow:Assets written to: saved_models/Model 2/Run-5/assets
# --- Starting trial: run-6
# {'filter_size_1': 3, 'filters_number': 96, 'filter_size_2': 5}
# Epoch 1/20
# 63/63 - 256s - loss: 1.2350 - accuracy: 0.4930 - val_loss: 1.0500 - val_accuracy: 0.5620
# Epoch 2/20
# 63/63 - 254s - loss: 0.9231 - accuracy: 0.6269 - val_loss: 1.0641 - val_accuracy: 0.5800
# Epoch 3/20
# 63/63 - 1240s - loss: 0.8170 - accuracy: 0.6738 - val_loss: 0.9506 - val_accuracy: 0.6220
# Epoch 4/20
# 63/63 - 214s - loss: 0.7572 - accuracy: 0.6906 - val_loss: 0.9781 - val_accuracy: 0.6100
# Epoch 5/20
# 63/63 - 227s - loss: 0.7286 - accuracy: 0.7010 - val_loss: 0.8395 - val_accuracy: 0.6620
# Epoch 6/20
# 63/63 - 233s - loss: 0.6732 - accuracy: 0.7293 - val_loss: 0.8401 - val_accuracy: 0.6780
# Epoch 7/20
# 63/63 - 7397s - loss: 0.6368 - accuracy: 0.7507 - val_loss: 0.8378 - val_accuracy: 0.6800
# Epoch 8/20
# 63/63 - 212s - loss: 0.6010 - accuracy: 0.7602 - val_loss: 0.7741 - val_accuracy: 0.7140
# Epoch 9/20
# 63/63 - 221s - loss: 0.5710 - accuracy: 0.7755 - val_loss: 0.7700 - val_accuracy: 0.7160
# Epoch 10/20
# 63/63 - 1162s - loss: 0.5670 - accuracy: 0.7762 - val_loss: 0.7536 - val_accuracy: 0.7240
# Epoch 11/20
# 63/63 - 218s - loss: 0.5092 - accuracy: 0.7987 - val_loss: 0.7568 - val_accuracy: 0.7400
# Epoch 12/20
# 63/63 - 225s - loss: 0.4860 - accuracy: 0.8182 - val_loss: 0.7679 - val_accuracy: 0.7300
# 16/16 [==============================] - 8s 464ms/step - loss: 0.7536 - accuracy: 0.7240
# INFO:tensorflow:Assets written to: saved_models/Model 2/Run-6/assets
# --- Starting trial: run-7
# {'filter_size_1': 3, 'filters_number': 128, 'filter_size_2': 3}
# Epoch 1/20
# 63/63 - 191s - loss: 1.1938 - accuracy: 0.4938 - val_loss: 1.0511 - val_accuracy: 0.5580
# Epoch 2/20
# 63/63 - 14559s - loss: 0.8609 - accuracy: 0.6538 - val_loss: 0.9022 - val_accuracy: 0.6640
# Epoch 3/20
# 63/63 - 3159s - loss: 0.7726 - accuracy: 0.6961 - val_loss: 0.8251 - val_accuracy: 0.6620
# Epoch 4/20
# 63/63 - 165s - loss: 0.7022 - accuracy: 0.7165 - val_loss: 0.8055 - val_accuracy: 0.6980
# Epoch 5/20
# 63/63 - 181s - loss: 0.6375 - accuracy: 0.7453 - val_loss: 0.8588 - val_accuracy: 0.6420
# Epoch 6/20
# 63/63 - 168s - loss: 0.6148 - accuracy: 0.7527 - val_loss: 0.7984 - val_accuracy: 0.6960
# Epoch 7/20
# 63/63 - 154s - loss: 0.5538 - accuracy: 0.7932 - val_loss: 0.8523 - val_accuracy: 0.7140
# Epoch 8/20
# 63/63 - 145s - loss: 0.5001 - accuracy: 0.8079 - val_loss: 0.7511 - val_accuracy: 0.7360
# Epoch 9/20
# 63/63 - 146s - loss: 0.4660 - accuracy: 0.8224 - val_loss: 0.7496 - val_accuracy: 0.7440
# Epoch 10/20
# 63/63 - 144s - loss: 0.4424 - accuracy: 0.8327 - val_loss: 0.7817 - val_accuracy: 0.7140
# Epoch 11/20
# 63/63 - 145s - loss: 0.4249 - accuracy: 0.8427 - val_loss: 0.8878 - val_accuracy: 0.7200
# 16/16 [==============================] - 5s 308ms/step - loss: 0.7496 - accuracy: 0.7440
# INFO:tensorflow:Assets written to: saved_models/Model 2/Run-7/assets
# --- Starting trial: run-8
# {'filter_size_1': 3, 'filters_number': 128, 'filter_size_2': 5}
# Epoch 1/20
# 63/63 - 278s - loss: 1.2532 - accuracy: 0.4800 - val_loss: 1.1193 - val_accuracy: 0.5320
# Epoch 2/20
# 63/63 - 297s - loss: 0.9362 - accuracy: 0.6161 - val_loss: 1.0079 - val_accuracy: 0.6080
# Epoch 3/20
# 63/63 - 299s - loss: 0.8408 - accuracy: 0.6676 - val_loss: 0.9173 - val_accuracy: 0.6300
# Epoch 4/20
# 63/63 - 286s - loss: 0.7635 - accuracy: 0.6846 - val_loss: 0.8807 - val_accuracy: 0.6400
# Epoch 5/20
# 63/63 - 452s - loss: 0.7005 - accuracy: 0.7180 - val_loss: 0.8192 - val_accuracy: 0.6900
# Epoch 6/20
# 63/63 - 314s - loss: 0.6664 - accuracy: 0.7273 - val_loss: 1.1920 - val_accuracy: 0.6000
# Epoch 7/20
# 63/63 - 325s - loss: 0.6238 - accuracy: 0.7488 - val_loss: 0.8112 - val_accuracy: 0.6900
# Epoch 8/20
# 63/63 - 312s - loss: 0.5870 - accuracy: 0.7745 - val_loss: 0.7834 - val_accuracy: 0.7060
# Epoch 9/20
# 63/63 - 295s - loss: 0.5388 - accuracy: 0.7950 - val_loss: 0.8487 - val_accuracy: 0.6740
# Epoch 10/20
# 63/63 - 277s - loss: 0.5282 - accuracy: 0.7982 - val_loss: 0.8553 - val_accuracy: 0.7020
# 16/16 [==============================] - 10s 602ms/step - loss: 0.7834 - accuracy: 0.7060
# INFO:tensorflow:Assets written to: saved_models/Model 2/Run-8/assets
# --- Starting trial: run-9
# {'filter_size_1': 5, 'filters_number': 32, 'filter_size_2': 3}
# Epoch 1/20
# 63/63 - 35s - loss: 1.1893 - accuracy: 0.4593 - val_loss: 1.0580 - val_accuracy: 0.5600
# Epoch 2/20
# 63/63 - 36s - loss: 0.9253 - accuracy: 0.6179 - val_loss: 0.9279 - val_accuracy: 0.6340
# Epoch 3/20
# 63/63 - 38s - loss: 0.8169 - accuracy: 0.6648 - val_loss: 0.8681 - val_accuracy: 0.6440
# Epoch 4/20
# 63/63 - 33s - loss: 0.7355 - accuracy: 0.6973 - val_loss: 0.8752 - val_accuracy: 0.6720
# Epoch 5/20
# 63/63 - 33s - loss: 0.7062 - accuracy: 0.7170 - val_loss: 0.8642 - val_accuracy: 0.6180
# Epoch 6/20
# 63/63 - 32s - loss: 0.6522 - accuracy: 0.7390 - val_loss: 0.7834 - val_accuracy: 0.6780
# Epoch 7/20
# 63/63 - 33s - loss: 0.6116 - accuracy: 0.7542 - val_loss: 0.7501 - val_accuracy: 0.7160
# Epoch 8/20
# 63/63 - 46s - loss: 0.5832 - accuracy: 0.7772 - val_loss: 0.7975 - val_accuracy: 0.6900
# Epoch 9/20
# 63/63 - 42s - loss: 0.5845 - accuracy: 0.7685 - val_loss: 0.8009 - val_accuracy: 0.7020
# 16/16 [==============================] - 1s 86ms/step - loss: 0.7501 - accuracy: 0.7160
# INFO:tensorflow:Assets written to: saved_models/Model 2/Run-9/assets
# --- Starting trial: run-10
# {'filter_size_1': 5, 'filters_number': 32, 'filter_size_2': 5}
# Epoch 1/20
# 63/63 - 55s - loss: 1.1900 - accuracy: 0.4770 - val_loss: 1.1063 - val_accuracy: 0.5480
# Epoch 2/20
# 63/63 - 49s - loss: 0.9212 - accuracy: 0.6191 - val_loss: 1.0108 - val_accuracy: 0.5740
# Epoch 3/20
# 63/63 - 48s - loss: 0.8518 - accuracy: 0.6513 - val_loss: 0.9245 - val_accuracy: 0.6360
# Epoch 4/20
# 63/63 - 48s - loss: 0.7852 - accuracy: 0.6733 - val_loss: 0.9060 - val_accuracy: 0.6380
# Epoch 5/20
# 63/63 - 49s - loss: 0.7377 - accuracy: 0.6998 - val_loss: 0.8901 - val_accuracy: 0.6400
# Epoch 6/20
# 63/63 - 48s - loss: 0.6989 - accuracy: 0.7243 - val_loss: 0.8187 - val_accuracy: 0.6840
# Epoch 7/20
# 63/63 - 51s - loss: 0.6510 - accuracy: 0.7443 - val_loss: 0.8352 - val_accuracy: 0.6320
# Epoch 8/20
# 63/63 - 48s - loss: 0.6314 - accuracy: 0.7572 - val_loss: 0.7983 - val_accuracy: 0.6900
# Epoch 9/20
# 63/63 - 50s - loss: 0.6118 - accuracy: 0.7615 - val_loss: 0.8355 - val_accuracy: 0.6760
# Epoch 10/20
# 63/63 - 51s - loss: 0.5830 - accuracy: 0.7750 - val_loss: 0.7890 - val_accuracy: 0.6980
# Epoch 11/20
# 63/63 - 54s - loss: 0.5445 - accuracy: 0.7860 - val_loss: 0.7522 - val_accuracy: 0.7300
# Epoch 12/20
# 63/63 - 62s - loss: 0.5075 - accuracy: 0.8044 - val_loss: 0.7563 - val_accuracy: 0.7220
# Epoch 13/20
# 63/63 - 58s - loss: 0.4845 - accuracy: 0.8152 - val_loss: 0.7836 - val_accuracy: 0.7180
# 16/16 [==============================] - 2s 102ms/step - loss: 0.7522 - accuracy: 0.7300
# INFO:tensorflow:Assets written to: saved_models/Model 2/Run-10/assets
# --- Starting trial: run-11
# {'filter_size_1': 5, 'filters_number': 64, 'filter_size_2': 3}
# Epoch 1/20
# 63/63 - 73s - loss: 1.1777 - accuracy: 0.4988 - val_loss: 1.0182 - val_accuracy: 0.5920
# Epoch 2/20
# 63/63 - 69s - loss: 0.8915 - accuracy: 0.6399 - val_loss: 0.8886 - val_accuracy: 0.6560
# Epoch 3/20
# 63/63 - 67s - loss: 0.8027 - accuracy: 0.6756 - val_loss: 0.8739 - val_accuracy: 0.6580
# Epoch 4/20
# 63/63 - 67s - loss: 0.7438 - accuracy: 0.6993 - val_loss: 0.8808 - val_accuracy: 0.6340
# Epoch 5/20
# 63/63 - 67s - loss: 0.6808 - accuracy: 0.7260 - val_loss: 0.8021 - val_accuracy: 0.6840
# Epoch 6/20
# 63/63 - 67s - loss: 0.6539 - accuracy: 0.7395 - val_loss: 0.8312 - val_accuracy: 0.6900
# Epoch 7/20
# 63/63 - 68s - loss: 0.5950 - accuracy: 0.7655 - val_loss: 0.7519 - val_accuracy: 0.6980
# Epoch 8/20
# 63/63 - 67s - loss: 0.5597 - accuracy: 0.7720 - val_loss: 0.8129 - val_accuracy: 0.6960
# Epoch 9/20
# 63/63 - 73s - loss: 0.5272 - accuracy: 0.7907 - val_loss: 0.7372 - val_accuracy: 0.7380
# Epoch 10/20
# 63/63 - 2765s - loss: 0.4931 - accuracy: 0.8024 - val_loss: 0.7224 - val_accuracy: 0.7300
# Epoch 11/20
# 63/63 - 70s - loss: 0.4499 - accuracy: 0.8312 - val_loss: 0.7580 - val_accuracy: 0.7380
# Epoch 12/20
# 63/63 - 77s - loss: 0.4186 - accuracy: 0.8394 - val_loss: 0.7216 - val_accuracy: 0.7460
# Epoch 13/20
# 63/63 - 79s - loss: 0.3866 - accuracy: 0.8566 - val_loss: 0.7862 - val_accuracy: 0.7220
# Epoch 14/20
# 63/63 - 81s - loss: 0.3859 - accuracy: 0.8571 - val_loss: 0.7887 - val_accuracy: 0.7260
# 16/16 [==============================] - 2s 151ms/step - loss: 0.7216 - accuracy: 0.7460
# INFO:tensorflow:Assets written to: saved_models/Model 2/Run-11/assets
# --- Starting trial: run-12
# {'filter_size_1': 5, 'filters_number': 64, 'filter_size_2': 5}
# Epoch 1/20
# 63/63 - 129s - loss: 1.1563 - accuracy: 0.5092 - val_loss: 1.1439 - val_accuracy: 0.5140
# Epoch 2/20
# 63/63 - 131s - loss: 0.8760 - accuracy: 0.6399 - val_loss: 1.0289 - val_accuracy: 0.5920
# Epoch 3/20
# 63/63 - 132s - loss: 0.7827 - accuracy: 0.6896 - val_loss: 0.8485 - val_accuracy: 0.6660
# Epoch 4/20
# 63/63 - 132s - loss: 0.7226 - accuracy: 0.7103 - val_loss: 0.8188 - val_accuracy: 0.6700
# Epoch 5/20
# 63/63 - 133s - loss: 0.6723 - accuracy: 0.7295 - val_loss: 1.0749 - val_accuracy: 0.6060
# Epoch 6/20
# 63/63 - 135s - loss: 0.6605 - accuracy: 0.7318 - val_loss: 0.8082 - val_accuracy: 0.6960
# Epoch 7/20
# 63/63 - 135s - loss: 0.5984 - accuracy: 0.7582 - val_loss: 0.8154 - val_accuracy: 0.6580
# Epoch 8/20
# 63/63 - 543s - loss: 0.5586 - accuracy: 0.7812 - val_loss: 0.7750 - val_accuracy: 0.7000
# Epoch 9/20
# 63/63 - 141s - loss: 0.5085 - accuracy: 0.8037 - val_loss: 0.7539 - val_accuracy: 0.7240
# Epoch 10/20
# 63/63 - 122s - loss: 0.4786 - accuracy: 0.8162 - val_loss: 0.7801 - val_accuracy: 0.7200
# Epoch 11/20
# 63/63 - 107s - loss: 0.4533 - accuracy: 0.8267 - val_loss: 0.7518 - val_accuracy: 0.7280
# Epoch 12/20
# 63/63 - 107s - loss: 0.4296 - accuracy: 0.8377 - val_loss: 0.8633 - val_accuracy: 0.6840
# Epoch 13/20
# 63/63 - 107s - loss: 0.4227 - accuracy: 0.8387 - val_loss: 0.8702 - val_accuracy: 0.7180
# 16/16 [==============================] - 3s 191ms/step - loss: 0.7518 - accuracy: 0.7280
# INFO:tensorflow:Assets written to: saved_models/Model 2/Run-12/assets
# --- Starting trial: run-13
# {'filter_size_1': 5, 'filters_number': 96, 'filter_size_2': 3}
# Epoch 1/20
# 63/63 - 114s - loss: 1.1574 - accuracy: 0.5055 - val_loss: 1.1534 - val_accuracy: 0.4980
# Epoch 2/20
# 63/63 - 110s - loss: 0.8978 - accuracy: 0.6424 - val_loss: 0.9215 - val_accuracy: 0.6480
# Epoch 3/20
# 63/63 - 445s - loss: 0.7791 - accuracy: 0.6886 - val_loss: 0.9763 - val_accuracy: 0.6060
# Epoch 4/20
# 63/63 - 132s - loss: 0.7163 - accuracy: 0.7103 - val_loss: 0.8319 - val_accuracy: 0.6820
# Epoch 5/20
# 63/63 - 140s - loss: 0.6829 - accuracy: 0.7203 - val_loss: 0.8340 - val_accuracy: 0.6900
# Epoch 6/20
# 63/63 - 112s - loss: 0.6172 - accuracy: 0.7547 - val_loss: 0.8474 - val_accuracy: 0.6540
# 16/16 [==============================] - 3s 201ms/step - loss: 0.8319 - accuracy: 0.6820
# INFO:tensorflow:Assets written to: saved_models/Model 2/Run-13/assets
# --- Starting trial: run-14
# {'filter_size_1': 5, 'filters_number': 96, 'filter_size_2': 5}
# Epoch 1/20
# 63/63 - 207s - loss: 1.2170 - accuracy: 0.4728 - val_loss: 1.0993 - val_accuracy: 0.5200
# Epoch 2/20
# 63/63 - 194s - loss: 0.8898 - accuracy: 0.6411 - val_loss: 0.9242 - val_accuracy: 0.6380
# Epoch 3/20
# 63/63 - 189s - loss: 0.8046 - accuracy: 0.6741 - val_loss: 0.9020 - val_accuracy: 0.6480
# Epoch 4/20
# 63/63 - 1011s - loss: 0.7232 - accuracy: 0.7015 - val_loss: 0.8489 - val_accuracy: 0.6800
# Epoch 5/20
# 63/63 - 205s - loss: 0.6920 - accuracy: 0.7268 - val_loss: 0.8352 - val_accuracy: 0.6500
# Epoch 6/20
# 63/63 - 182s - loss: 0.6505 - accuracy: 0.7428 - val_loss: 0.7843 - val_accuracy: 0.7060
# Epoch 7/20
# 63/63 - 2021s - loss: 0.6228 - accuracy: 0.7500 - val_loss: 0.7387 - val_accuracy: 0.7040
# Epoch 8/20
# 63/63 - 212s - loss: 0.5543 - accuracy: 0.7852 - val_loss: 0.8337 - val_accuracy: 0.7140
# Epoch 9/20
# 63/63 - 228s - loss: 0.5303 - accuracy: 0.7912 - val_loss: 0.8295 - val_accuracy: 0.6900
# 16/16 [==============================] - 8s 479ms/step - loss: 0.7387 - accuracy: 0.7040
# INFO:tensorflow:Assets written to: saved_models/Model 2/Run-14/assets
# --- Starting trial: run-15
# {'filter_size_1': 5, 'filters_number': 128, 'filter_size_2': 3}
# Epoch 1/20
# 63/63 - 207s - loss: 1.2286 - accuracy: 0.4735 - val_loss: 1.0125 - val_accuracy: 0.5980
# Epoch 2/20
# 63/63 - 202s - loss: 0.8971 - accuracy: 0.6274 - val_loss: 0.9312 - val_accuracy: 0.6240
# Epoch 3/20
# 63/63 - 14074s - loss: 0.8050 - accuracy: 0.6711 - val_loss: 0.8393 - val_accuracy: 0.6900
# Epoch 4/20
# 63/63 - 199s - loss: 0.7244 - accuracy: 0.7078 - val_loss: 0.8599 - val_accuracy: 0.6320
# Epoch 5/20
# 63/63 - 196s - loss: 0.6768 - accuracy: 0.7275 - val_loss: 0.8197 - val_accuracy: 0.6760
# Epoch 6/20
# 63/63 - 196s - loss: 0.6536 - accuracy: 0.7358 - val_loss: 0.8082 - val_accuracy: 0.6860
# Epoch 7/20
# 63/63 - 166s - loss: 0.6189 - accuracy: 0.7522 - val_loss: 0.7925 - val_accuracy: 0.6820
# Epoch 8/20
# 63/63 - 173s - loss: 0.5861 - accuracy: 0.7727 - val_loss: 0.8436 - val_accuracy: 0.6580
# Epoch 9/20
# 63/63 - 156s - loss: 0.5453 - accuracy: 0.7865 - val_loss: 0.7680 - val_accuracy: 0.7020
# Epoch 10/20
# 63/63 - 156s - loss: 0.4800 - accuracy: 0.8134 - val_loss: 0.7733 - val_accuracy: 0.7220
# Epoch 11/20
# 63/63 - 155s - loss: 0.4497 - accuracy: 0.8252 - val_loss: 0.7465 - val_accuracy: 0.7380
# Epoch 12/20
# 63/63 - 154s - loss: 0.4390 - accuracy: 0.8262 - val_loss: 0.7833 - val_accuracy: 0.7300
# Epoch 13/20
# 63/63 - 184s - loss: 0.4107 - accuracy: 0.8467 - val_loss: 0.7624 - val_accuracy: 0.7460
# 16/16 [==============================] - 9s 565ms/step - loss: 0.7465 - accuracy: 0.7380
# INFO:tensorflow:Assets written to: saved_models/Model 2/Run-15/assets
# --- Starting trial: run-16
# {'filter_size_1': 5, 'filters_number': 128, 'filter_size_2': 5}
# Epoch 1/20
# 63/63 - 359s - loss: 1.2023 - accuracy: 0.4873 - val_loss: 1.0641 - val_accuracy: 0.5660
# Epoch 2/20
# 63/63 - 362s - loss: 0.9136 - accuracy: 0.6286 - val_loss: 0.9831 - val_accuracy: 0.5840
# Epoch 3/20
# 63/63 - 314s - loss: 0.8607 - accuracy: 0.6571 - val_loss: 0.9504 - val_accuracy: 0.6300
# Epoch 4/20
# 63/63 - 302s - loss: 0.8056 - accuracy: 0.6706 - val_loss: 0.9329 - val_accuracy: 0.6340
# Epoch 5/20
# 63/63 - 326s - loss: 0.7180 - accuracy: 0.7070 - val_loss: 0.8538 - val_accuracy: 0.6680
# Epoch 6/20
# 63/63 - 323s - loss: 0.7163 - accuracy: 0.7105 - val_loss: 0.8486 - val_accuracy: 0.6840
# Epoch 7/20
# 63/63 - 317s - loss: 0.6674 - accuracy: 0.7315 - val_loss: 0.8508 - val_accuracy: 0.6800
# Epoch 8/20
# 63/63 - 2102s - loss: 0.6073 - accuracy: 0.7552 - val_loss: 0.8150 - val_accuracy: 0.6880
# Epoch 9/20
# 63/63 - 364s - loss: 0.5989 - accuracy: 0.7637 - val_loss: 0.8135 - val_accuracy: 0.7120
# Epoch 10/20
# 63/63 - 378s - loss: 0.5483 - accuracy: 0.7852 - val_loss: 0.9367 - val_accuracy: 0.6980
# Epoch 11/20
# 63/63 - 1053s - loss: 0.5611 - accuracy: 0.7785 - val_loss: 0.7273 - val_accuracy: 0.7380
# Epoch 12/20
# 63/63 - 330s - loss: 0.4902 - accuracy: 0.8034 - val_loss: 0.7477 - val_accuracy: 0.7220
# Epoch 13/20
# 63/63 - 331s - loss: 0.4532 - accuracy: 0.8214 - val_loss: 0.8339 - val_accuracy: 0.7340
# 16/16 [==============================] - 11s 683ms/step - loss: 0.7273 - accuracy: 0.7380
# INFO:tensorflow:Assets written to: saved_models/Model 2/Run-16/assets
# --- Starting trial: run-17
# {'filter_size_1': 7, 'filters_number': 32, 'filter_size_2': 3}
# Epoch 1/20
# 63/63 - 59s - loss: 1.1560 - accuracy: 0.4908 - val_loss: 1.1278 - val_accuracy: 0.5300
# Epoch 2/20
# 63/63 - 46s - loss: 0.9329 - accuracy: 0.6159 - val_loss: 0.9664 - val_accuracy: 0.6040
# Epoch 3/20
# 63/63 - 46s - loss: 0.8384 - accuracy: 0.6611 - val_loss: 0.9055 - val_accuracy: 0.6400
# Epoch 4/20
# 63/63 - 46s - loss: 0.7612 - accuracy: 0.6941 - val_loss: 0.9099 - val_accuracy: 0.6580
# Epoch 5/20
# 63/63 - 46s - loss: 0.7232 - accuracy: 0.7103 - val_loss: 0.8699 - val_accuracy: 0.6400
# Epoch 6/20
# 63/63 - 48s - loss: 0.6979 - accuracy: 0.7158 - val_loss: 0.8820 - val_accuracy: 0.6300
# Epoch 7/20
# 63/63 - 54s - loss: 0.6863 - accuracy: 0.7180 - val_loss: 0.8380 - val_accuracy: 0.7000
# Epoch 8/20
# 63/63 - 43s - loss: 0.6323 - accuracy: 0.7435 - val_loss: 0.8250 - val_accuracy: 0.7060
# Epoch 9/20
# 63/63 - 44s - loss: 0.6132 - accuracy: 0.7575 - val_loss: 0.7906 - val_accuracy: 0.7020
# Epoch 10/20
# 63/63 - 47s - loss: 0.5453 - accuracy: 0.7855 - val_loss: 0.8769 - val_accuracy: 0.6740
# Epoch 11/20
# 63/63 - 48s - loss: 0.5100 - accuracy: 0.8007 - val_loss: 0.7482 - val_accuracy: 0.7360
# Epoch 12/20
# 63/63 - 42s - loss: 0.5046 - accuracy: 0.7945 - val_loss: 0.7461 - val_accuracy: 0.7320
# Epoch 13/20
# 63/63 - 40s - loss: 0.4727 - accuracy: 0.8132 - val_loss: 0.7412 - val_accuracy: 0.7220
# Epoch 14/20
# 63/63 - 39s - loss: 0.4492 - accuracy: 0.8289 - val_loss: 0.7251 - val_accuracy: 0.7280
# Epoch 15/20
# 63/63 - 40s - loss: 0.4251 - accuracy: 0.8369 - val_loss: 0.8311 - val_accuracy: 0.6980
# Epoch 16/20
# 63/63 - 40s - loss: 0.4450 - accuracy: 0.8272 - val_loss: 0.7696 - val_accuracy: 0.7360
# 16/16 [==============================] - 1s 74ms/step - loss: 0.7251 - accuracy: 0.7280
# INFO:tensorflow:Assets written to: saved_models/Model 2/Run-17/assets
# --- Starting trial: run-18
# {'filter_size_1': 7, 'filters_number': 32, 'filter_size_2': 5}
# Epoch 1/20
# 63/63 - 61s - loss: 1.1705 - accuracy: 0.4690 - val_loss: 1.0565 - val_accuracy: 0.5820
# Epoch 2/20
# 63/63 - 55s - loss: 0.9194 - accuracy: 0.6206 - val_loss: 0.9941 - val_accuracy: 0.5860
# Epoch 3/20
# 63/63 - 60s - loss: 0.8142 - accuracy: 0.6676 - val_loss: 0.8784 - val_accuracy: 0.6520
# Epoch 4/20
# 63/63 - 57s - loss: 0.7645 - accuracy: 0.6863 - val_loss: 0.8905 - val_accuracy: 0.6620
# Epoch 5/20
# 63/63 - 57s - loss: 0.7109 - accuracy: 0.7150 - val_loss: 0.8230 - val_accuracy: 0.6720
# Epoch 6/20
# 63/63 - 57s - loss: 0.6945 - accuracy: 0.7175 - val_loss: 0.8118 - val_accuracy: 0.6660
# Epoch 7/20
# 63/63 - 70s - loss: 0.6638 - accuracy: 0.7298 - val_loss: 0.7996 - val_accuracy: 0.6640
# Epoch 8/20
# 63/63 - 54s - loss: 0.6163 - accuracy: 0.7615 - val_loss: 0.7297 - val_accuracy: 0.7040
# Epoch 9/20
# 63/63 - 59s - loss: 0.5885 - accuracy: 0.7667 - val_loss: 0.8296 - val_accuracy: 0.6800
# Epoch 10/20
# 63/63 - 64s - loss: 0.5597 - accuracy: 0.7832 - val_loss: 0.7242 - val_accuracy: 0.7120
# Epoch 11/20
# 63/63 - 60s - loss: 0.5396 - accuracy: 0.7852 - val_loss: 0.7127 - val_accuracy: 0.7180
# Epoch 12/20
# 63/63 - 62s - loss: 0.4958 - accuracy: 0.8054 - val_loss: 0.7230 - val_accuracy: 0.7220
# Epoch 13/20
# 63/63 - 58s - loss: 0.4856 - accuracy: 0.8124 - val_loss: 0.7956 - val_accuracy: 0.7040
# 16/16 [==============================] - 2s 118ms/step - loss: 0.7127 - accuracy: 0.7180
# INFO:tensorflow:Assets written to: saved_models/Model 2/Run-18/assets
# --- Starting trial: run-19
# {'filter_size_1': 7, 'filters_number': 64, 'filter_size_2': 3}
# Epoch 1/20
# 63/63 - 85s - loss: 1.2043 - accuracy: 0.4803 - val_loss: 1.0676 - val_accuracy: 0.5460
# Epoch 2/20
# 63/63 - 84s - loss: 0.9215 - accuracy: 0.6181 - val_loss: 0.9722 - val_accuracy: 0.5880
# Epoch 3/20
# 63/63 - 78s - loss: 0.8280 - accuracy: 0.6591 - val_loss: 0.9318 - val_accuracy: 0.6300
# Epoch 4/20
# 63/63 - 78s - loss: 0.7490 - accuracy: 0.6956 - val_loss: 0.8466 - val_accuracy: 0.6620
# Epoch 5/20
# 63/63 - 75s - loss: 0.7339 - accuracy: 0.6966 - val_loss: 0.9033 - val_accuracy: 0.6360
# Epoch 6/20
# 63/63 - 76s - loss: 0.6941 - accuracy: 0.7198 - val_loss: 0.8520 - val_accuracy: 0.6540
# 16/16 [==============================] - 2s 149ms/step - loss: 0.8466 - accuracy: 0.6620
# INFO:tensorflow:Assets written to: saved_models/Model 2/Run-19/assets
# --- Starting trial: run-20
# {'filter_size_1': 7, 'filters_number': 64, 'filter_size_2': 5}
# Epoch 1/20
# 63/63 - 112s - loss: 1.2076 - accuracy: 0.4675 - val_loss: 1.3442 - val_accuracy: 0.5080
# Epoch 2/20
# 63/63 - 109s - loss: 0.9381 - accuracy: 0.6139 - val_loss: 0.9562 - val_accuracy: 0.5940
# Epoch 3/20
# 63/63 - 112s - loss: 0.8510 - accuracy: 0.6536 - val_loss: 0.8982 - val_accuracy: 0.6440
# Epoch 4/20
# 63/63 - 115s - loss: 0.7799 - accuracy: 0.6848 - val_loss: 0.8630 - val_accuracy: 0.6680
# Epoch 5/20
# 63/63 - 110s - loss: 0.7286 - accuracy: 0.7018 - val_loss: 0.8478 - val_accuracy: 0.6720
# Epoch 6/20
# 63/63 - 113s - loss: 0.7037 - accuracy: 0.7198 - val_loss: 0.8638 - val_accuracy: 0.6500
# Epoch 7/20
# 63/63 - 110s - loss: 0.6751 - accuracy: 0.7258 - val_loss: 0.8689 - val_accuracy: 0.6580
# 16/16 [==============================] - 3s 202ms/step - loss: 0.8478 - accuracy: 0.6720
# INFO:tensorflow:Assets written to: saved_models/Model 2/Run-20/assets
# --- Starting trial: run-21
# {'filter_size_1': 7, 'filters_number': 96, 'filter_size_2': 3}
# Epoch 1/20
# 63/63 - 114s - loss: 1.2493 - accuracy: 0.4503 - val_loss: 1.0576 - val_accuracy: 0.5620
# Epoch 2/20
# 63/63 - 1921s - loss: 0.9362 - accuracy: 0.6171 - val_loss: 0.9903 - val_accuracy: 0.5920
# Epoch 3/20
# 63/63 - 132s - loss: 0.8556 - accuracy: 0.6586 - val_loss: 0.9288 - val_accuracy: 0.6320
# Epoch 4/20
# 63/63 - 148s - loss: 0.8283 - accuracy: 0.6646 - val_loss: 0.8923 - val_accuracy: 0.6400
# Epoch 5/20
# 63/63 - 157s - loss: 0.7551 - accuracy: 0.6963 - val_loss: 0.9108 - val_accuracy: 0.6380
# Epoch 6/20
# 63/63 - 155s - loss: 0.7005 - accuracy: 0.7180 - val_loss: 0.8627 - val_accuracy: 0.6500
# Epoch 7/20
# 63/63 - 144s - loss: 0.6594 - accuracy: 0.7308 - val_loss: 0.7865 - val_accuracy: 0.7120
# Epoch 8/20
# 63/63 - 144s - loss: 0.6196 - accuracy: 0.7498 - val_loss: 0.7953 - val_accuracy: 0.6880
# Epoch 9/20
# 63/63 - 130s - loss: 0.6257 - accuracy: 0.7602 - val_loss: 0.8368 - val_accuracy: 0.6880
# 16/16 [==============================] - 7s 409ms/step - loss: 0.7865 - accuracy: 0.7120
# INFO:tensorflow:Assets written to: saved_models/Model 2/Run-21/assets
# --- Starting trial: run-22
# {'filter_size_1': 7, 'filters_number': 96, 'filter_size_2': 5}
# Epoch 1/20
# 63/63 - 258s - loss: 1.3049 - accuracy: 0.4008 - val_loss: 1.0557 - val_accuracy: 0.5660
# Epoch 2/20
# 63/63 - 226s - loss: 0.9483 - accuracy: 0.6121 - val_loss: 1.0198 - val_accuracy: 0.5720
# Epoch 3/20
# 63/63 - 184s - loss: 0.8470 - accuracy: 0.6573 - val_loss: 0.9610 - val_accuracy: 0.6080
# Epoch 4/20
# 63/63 - 193s - loss: 0.7822 - accuracy: 0.6888 - val_loss: 0.9923 - val_accuracy: 0.6140
# Epoch 5/20
# 63/63 - 183s - loss: 0.7383 - accuracy: 0.7040 - val_loss: 0.8455 - val_accuracy: 0.6760
# Epoch 6/20
# 63/63 - 3036s - loss: 0.6894 - accuracy: 0.7218 - val_loss: 0.8371 - val_accuracy: 0.6780
# Epoch 7/20
# 63/63 - 240s - loss: 0.6655 - accuracy: 0.7355 - val_loss: 0.8594 - val_accuracy: 0.6560
# Epoch 8/20
# 63/63 - 258s - loss: 0.6449 - accuracy: 0.7418 - val_loss: 0.8057 - val_accuracy: 0.6980
# Epoch 9/20
# 63/63 - 1296s - loss: 0.6403 - accuracy: 0.7438 - val_loss: 0.8115 - val_accuracy: 0.7140
# Epoch 10/20
# 63/63 - 210s - loss: 0.5873 - accuracy: 0.7630 - val_loss: 0.8009 - val_accuracy: 0.7060
# Epoch 11/20
# 63/63 - 229s - loss: 0.6152 - accuracy: 0.7547 - val_loss: 0.8271 - val_accuracy: 0.6760
# Epoch 12/20
# 63/63 - 238s - loss: 0.5463 - accuracy: 0.7835 - val_loss: 0.7802 - val_accuracy: 0.7220
# Epoch 13/20
# 63/63 - 481s - loss: 0.5209 - accuracy: 0.7917 - val_loss: 0.8279 - val_accuracy: 0.6980
# Epoch 14/20
# 63/63 - 2001s - loss: 0.5003 - accuracy: 0.8022 - val_loss: 0.7692 - val_accuracy: 0.7340
# Epoch 15/20
# 63/63 - 212s - loss: 0.4959 - accuracy: 0.8037 - val_loss: 0.7542 - val_accuracy: 0.7140
# Epoch 16/20
# 63/63 - 228s - loss: 0.4396 - accuracy: 0.8302 - val_loss: 0.7241 - val_accuracy: 0.7420
# Epoch 17/20
# 63/63 - 240s - loss: 0.4253 - accuracy: 0.8372 - val_loss: 0.7390 - val_accuracy: 0.7360
# Epoch 18/20
# 63/63 - 8417s - loss: 0.4341 - accuracy: 0.8382 - val_loss: 0.8052 - val_accuracy: 0.7140
# 16/16 [==============================] - 6s 351ms/step - loss: 0.7241 - accuracy: 0.7420
# INFO:tensorflow:Assets written to: saved_models/Model 2/Run-22/assets
# --- Starting trial: run-23
# {'filter_size_1': 7, 'filters_number': 128, 'filter_size_2': 3}
# Epoch 1/20
# 63/63 - 6319s - loss: 1.2332 - accuracy: 0.4748 - val_loss: 1.0670 - val_accuracy: 0.5640
# Epoch 2/20
# 63/63 - 8165s - loss: 0.9048 - accuracy: 0.6371 - val_loss: 0.9606 - val_accuracy: 0.6100
# Epoch 3/20
# 63/63 - 4661s - loss: 0.8293 - accuracy: 0.6596 - val_loss: 0.9660 - val_accuracy: 0.6060
# Epoch 4/20
# 63/63 - 186s - loss: 0.7654 - accuracy: 0.6891 - val_loss: 0.9229 - val_accuracy: 0.6380
# Epoch 5/20
# 63/63 - 194s - loss: 0.6820 - accuracy: 0.7213 - val_loss: 0.8777 - val_accuracy: 0.6300
# Epoch 6/20
# 63/63 - 197s - loss: 0.6933 - accuracy: 0.7218 - val_loss: 0.8927 - val_accuracy: 0.6540
# Epoch 7/20
# 63/63 - 198s - loss: 0.6550 - accuracy: 0.7360 - val_loss: 0.8053 - val_accuracy: 0.6960
# Epoch 8/20
# 63/63 - 204s - loss: 0.6066 - accuracy: 0.7517 - val_loss: 0.7519 - val_accuracy: 0.7240
# Epoch 9/20
# 63/63 - 211s - loss: 0.5395 - accuracy: 0.7875 - val_loss: 0.7711 - val_accuracy: 0.7080
# Epoch 10/20
# 63/63 - 207s - loss: 0.5198 - accuracy: 0.7987 - val_loss: 0.7154 - val_accuracy: 0.7400
# Epoch 11/20
# 63/63 - 210s - loss: 0.4592 - accuracy: 0.8214 - val_loss: 0.7031 - val_accuracy: 0.7340
# Epoch 12/20
# 63/63 - 209s - loss: 0.4674 - accuracy: 0.8184 - val_loss: 0.7397 - val_accuracy: 0.7500
# Epoch 13/20
# 63/63 - 211s - loss: 0.4384 - accuracy: 0.8302 - val_loss: 0.7150 - val_accuracy: 0.7440
# 16/16 [==============================] - 8s 490ms/step - loss: 0.7031 - accuracy: 0.7340
# INFO:tensorflow:Assets written to: saved_models/Model 2/Run-23/assets
# --- Starting trial: run-24
# {'filter_size_1': 7, 'filters_number': 128, 'filter_size_2': 5}
# Epoch 1/20
# 63/63 - 390s - loss: 1.3436 - accuracy: 0.4048 - val_loss: 1.1131 - val_accuracy: 0.5120
# Epoch 2/20
# 63/63 - 392s - loss: 0.9724 - accuracy: 0.5972 - val_loss: 0.9717 - val_accuracy: 0.6080
# Epoch 3/20
# 63/63 - 402s - loss: 0.8340 - accuracy: 0.6656 - val_loss: 0.8904 - val_accuracy: 0.6500
# Epoch 4/20
# 63/63 - 2319s - loss: 0.7990 - accuracy: 0.6741 - val_loss: 0.8883 - val_accuracy: 0.6600
# Epoch 5/20
# 63/63 - 344s - loss: 0.7778 - accuracy: 0.6881 - val_loss: 0.8755 - val_accuracy: 0.6420
# Epoch 6/20
# 63/63 - 354s - loss: 0.7273 - accuracy: 0.7018 - val_loss: 0.8618 - val_accuracy: 0.6540
# Epoch 7/20
# 63/63 - 324s - loss: 0.6849 - accuracy: 0.7238 - val_loss: 0.7881 - val_accuracy: 0.6760
# Epoch 8/20
# 63/63 - 397s - loss: 0.6616 - accuracy: 0.7390 - val_loss: 0.7924 - val_accuracy: 0.6960
# Epoch 9/20
# 63/63 - 336s - loss: 0.6328 - accuracy: 0.7440 - val_loss: 0.8082 - val_accuracy: 0.6840
# 16/16 [==============================] - 11s 689ms/step - loss: 0.7881 - accuracy: 0.6760
# INFO:tensorflow:Assets written to: saved_models/Model 2/Run-24/assets

# %%
# Loading a model to evaluate on the test set
model = tf.keras.models.load_model(r"saved_models/Model 2/Run-1")

# %%
test_loss, test_accuracy = model.evaluate(images_test,labels_test)
# Out:
# 16/16 [==============================] - 2s 64ms/step - loss: 0.8034 - accuracy: 0.7080

# %%
# Printing the test results
print('Test loss: {0:.4f}. Test accuracy: {1:.2f}%'.format(test_loss, test_accuracy*100.))
# Out:
# Test loss: 0.8034. Test accuracy: 70.80%

# %%
# %load_ext tensorboard
# %tensorboard --logdir "Logs/Model 2/hparam_tuning"
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6013 (pid 15483), started 0:08:12 ago. (Use '!kill 15483' to kill it.)
#       <iframe id="tensorboard-frame-2980a51fedf44d77" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-2980a51fedf44d77");
#           const url = new URL("/", window.location);
#           const port = 6013;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %load_ext tensorboard
# %tensorboard --logdir "Logs/Model 2/fit"
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# ERROR: Timed out waiting for TensorBoard to start. It may still be running as pid 15906.
