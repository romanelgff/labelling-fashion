# %% [markdown]
# Since we can't improve this model through tuning it, we might as well get a better accuracy using L2-regularisation and dropo

# %%
import io
import itertools

import numpy as np
import sklearn.metrics

import tensorflow as tf
from tensorboard.plugins.hparams import api as hp

import matplotlib.pyplot as plt

# %%
# Loading the datasets
data_train = np.load(r"Dataset/Trousers & Jeans - All - Train.npz")
data_val = np.load(r"Dataset/Trousers & Jeans - All - Validation.npz")
data_test = np.load(r"Dataset/Trousers & Jeans - All - Test.npz")

# %%
# Extracting the arrays from the imported data
images_train = data_train['images']
labels_train = data_train['labels']

images_val = data_val['images']
labels_val = data_val['labels']

images_test = data_test['images']
labels_test = data_test['labels']

# %%
# Scaling the pixel values of all images 
images_train = images_train/255.0
images_val = images_val/255.0
images_test = images_test/255.0

# %%
# Defining the hyperparameters we would tune, and their values to be tested
HP_FILTER_SIZE_1 = hp.HParam('filter_size_1', hp.Discrete([3,5,7]))
HP_FILTER_NUM = hp.HParam('filters_number', hp.Discrete([32,64,96,128]))
HP_FILTER_SIZE_2 = hp.HParam('filter_size_2', hp.Discrete([3,5]))
HP_DENSE_SIZE = hp.HParam('dense_size', hp.Discrete([256,512,1024]))

METRIC_ACCURACY = 'accuracy'

# Logging setup info
with tf.summary.create_file_writer(r'Logs/Model 3/hparam_tuning/').as_default():
    hp.hparams_config(
        hparams=[HP_FILTER_SIZE_1, HP_FILTER_NUM, HP_FILTER_SIZE_2, HP_DENSE_SIZE],
        metrics=[hp.Metric(METRIC_ACCURACY, display_name='Accuracy')],
    )

# %%
EPOCHS = 20
BATCH_SIZE = 64

# %%
# Wrapping our model and training in a function
def train_test_model(hparams, session_num):
    
    # Outlining the model/architecture of our CNN
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(hparams[HP_FILTER_NUM], hparams[HP_FILTER_SIZE_1], activation='relu', input_shape=(120,90,3)),
        tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
        tf.keras.layers.Conv2D(hparams[HP_FILTER_NUM], hparams[HP_FILTER_SIZE_2], activation='relu'),
        tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(hparams[HP_DENSE_SIZE], activation='relu'),
        tf.keras.layers.Dense(4)
    ])
    
    # Defining the loss function
    loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

    # Compiling the model
    model.compile(optimizer='adam', loss=loss_fn, metrics=['accuracy'])

    # Defining the logging directory
    log_dir = "Logs/Model 3/fit/" + "run-{}".format(session_num)
    
    def plot_confusion_matrix(cm, class_names):
        """
        Returns a matplotlib figure containing the plotted confusion matrix.

        Args:
          cm (array, shape = [n, n]): a confusion matrix of integer classes
          class_names (array, shape = [n]): String names of the integer classes
        """
        figure = plt.figure(figsize=(12, 12))
        plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
        plt.title("Confusion matrix")
        plt.colorbar()
        tick_marks = np.arange(len(class_names))
        plt.xticks(tick_marks, class_names, rotation=45)
        plt.yticks(tick_marks, class_names)

        # Normalize the confusion matrix.
        cm = np.around(cm.astype('float') / cm.sum(axis=1)[:, np.newaxis], decimals=2)

        # Use white text if squares are dark; otherwise black.
        threshold = cm.max() / 2.
        for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
            color = "white" if cm[i, j] > threshold else "black"
            plt.text(j, i, cm[i, j], horizontalalignment="center", color=color)

        plt.tight_layout()
        plt.ylabel('True label')
        plt.xlabel('Predicted label')
        return figure  
    
    
    def plot_to_image(figure):
        """Converts the matplotlib plot specified by 'figure' to a PNG image and
        returns it. The supplied figure is closed and inaccessible after this call."""
        # Save the plot to a PNG in memory.
        buf = io.BytesIO()
        plt.savefig(buf, format='png')
        # Closing the figure prevents it from being displayed directly inside
        # the notebook.
        plt.close(figure)
        buf.seek(0)
        # Convert PNG buffer to TF image
        image = tf.image.decode_png(buf.getvalue(), channels=4)
        # Add the batch dimension
        image = tf.expand_dims(image, 0)
        return image
    
    
    # Defining a file writer for Confusion Matrix logging purposes
    file_writer_cm = tf.summary.create_file_writer(log_dir + '/cm')
    
    
    def log_confusion_matrix(epoch, logs):
        # Use the model to predict the values from the validation dataset.
        test_pred_raw = model.predict(images_val)
        test_pred = np.argmax(test_pred_raw, axis=1)

        # Calculate the confusion matrix.
        cm = sklearn.metrics.confusion_matrix(labels_val, test_pred)
        # Log the confusion matrix as an image summary.
        figure = plot_confusion_matrix(cm, class_names=['Trousers Male', 'Jeans Male', 'Trousers Female', "Jeans Female"])
        cm_image = plot_to_image(figure)

        # Log the confusion matrix as an image summary.
        with file_writer_cm.as_default():
            tf.summary.image("Confusion Matrix", cm_image, step=epoch)
    
    
    # Define the Tensorboard and Confusion Matrix callbacks.
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1, profile_batch=0)
    cm_callback = tf.keras.callbacks.LambdaCallback(on_epoch_end=log_confusion_matrix)

    
    # Defining early stopping to prevent overfitting
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor = 'val_loss',
        mode = 'auto',
        min_delta = 0,
        patience = 2,
        verbose = 0, 
        restore_best_weights = True
    )
    
    # Training the model
    model.fit(
        images_train,
        labels_train,
        epochs = EPOCHS,
        batch_size = BATCH_SIZE,
        callbacks = [tensorboard_callback, cm_callback, early_stopping],
        validation_data = (images_val,labels_val),
        verbose = 2
    )
    
    # Evaluating the model's performance on the validation set
    _, accuracy = model.evaluate(images_val,labels_val)
    
    # Saving the current model for future reference
    model.save(r"saved_models/Model 3/Run-{}".format(session_num))
    
    return accuracy

# %%
# Creating a function to log the resuls
def run(log_dir, hparams, session_num):
    
    with tf.summary.create_file_writer(log_dir).as_default():
        hp.hparams(hparams)  # record the values used in this trial
        accuracy = train_test_model(hparams, session_num)
        tf.summary.scalar(METRIC_ACCURACY, accuracy, step=1)

# %%
session_num = 1

for filter_size_1 in HP_FILTER_SIZE_1.domain.values:
    for filter_num in HP_FILTER_NUM.domain.values:
        for filter_size_2 in HP_FILTER_SIZE_2.domain.values:
            for dense_size in HP_DENSE_SIZE.domain.values:

                hparams = {
                    HP_FILTER_SIZE_1: filter_size_1,
                    HP_FILTER_NUM: filter_num,
                    HP_FILTER_SIZE_2: filter_size_2,
                    HP_DENSE_SIZE: dense_size
                }

                run_name = "run-%d" % session_num
                print('--- Starting trial: %s' % run_name)
                print({h.name: hparams[h] for h in hparams})
                run('Logs/Model 3/hparam_tuning/' + run_name, hparams, session_num)

                session_num += 1
# Out:
# --- Starting trial: run-1
# {'filter_size_1': 3, 'filters_number': 32, 'filter_size_2': 3, 'dense_size': 256}
# Epoch 1/20
# 63/63 - 32s - loss: 1.2937 - accuracy: 0.4868 - val_loss: 0.9952 - val_accuracy: 0.5640
# Epoch 2/20
# 63/63 - 28s - loss: 0.8537 - accuracy: 0.6516 - val_loss: 0.9133 - val_accuracy: 0.6080
# Epoch 3/20
# 63/63 - 29s - loss: 0.7291 - accuracy: 0.7105 - val_loss: 0.8066 - val_accuracy: 0.6700
# Epoch 4/20
# 63/63 - 28s - loss: 0.6571 - accuracy: 0.7348 - val_loss: 0.7858 - val_accuracy: 0.7140
# Epoch 5/20
# 63/63 - 29s - loss: 0.6000 - accuracy: 0.7632 - val_loss: 0.8175 - val_accuracy: 0.6980
# Epoch 6/20
# 63/63 - 28s - loss: 0.5311 - accuracy: 0.7920 - val_loss: 0.8567 - val_accuracy: 0.7040
# 16/16 [==============================] - 1s 68ms/step - loss: 0.7858 - accuracy: 0.7140 0s - loss: 0.8002
# INFO:tensorflow:Assets written to: saved_models/Model 3/Run-1/assets
# --- Starting trial: run-2
# {'filter_size_1': 3, 'filters_number': 32, 'filter_size_2': 3, 'dense_size': 512}
# Epoch 1/20
# 63/63 - 32s - loss: 1.2382 - accuracy: 0.4965 - val_loss: 0.9871 - val_accuracy: 0.5840
# Epoch 2/20
# 63/63 - 34s - loss: 0.8602 - accuracy: 0.6511 - val_loss: 0.9215 - val_accuracy: 0.6060
# Epoch 3/20
# 63/63 - 31s - loss: 0.7417 - accuracy: 0.6988 - val_loss: 0.8651 - val_accuracy: 0.6220
# Epoch 4/20
# 63/63 - 33s - loss: 0.6651 - accuracy: 0.7403 - val_loss: 0.8837 - val_accuracy: 0.6480
# Epoch 5/20
# 63/63 - 32s - loss: 0.6048 - accuracy: 0.7592 - val_loss: 0.7441 - val_accuracy: 0.7280
# Epoch 6/20
# 63/63 - 31s - loss: 0.5516 - accuracy: 0.7750 - val_loss: 0.7515 - val_accuracy: 0.7300
# Epoch 7/20
# 63/63 - 30s - loss: 0.4619 - accuracy: 0.8229 - val_loss: 0.7976 - val_accuracy: 0.7040
# 16/16 [==============================] - 1s 71ms/step - loss: 0.7441 - accuracy: 0.7280
# INFO:tensorflow:Assets written to: saved_models/Model 3/Run-2/assets
# --- Starting trial: run-3
# {'filter_size_1': 3, 'filters_number': 32, 'filter_size_2': 3, 'dense_size': 1024}
# Epoch 1/20
# 63/63 - 38s - loss: 1.3957 - accuracy: 0.5212 - val_loss: 0.9942 - val_accuracy: 0.5880
# Epoch 2/20
# 63/63 - 37s - loss: 0.8215 - accuracy: 0.6628 - val_loss: 0.8747 - val_accuracy: 0.6340
# Epoch 3/20
# 63/63 - 38s - loss: 0.7412 - accuracy: 0.6998 - val_loss: 0.9387 - val_accuracy: 0.6420
# Epoch 4/20
# 63/63 - 38s - loss: 0.6479 - accuracy: 0.7340 - val_loss: 0.8560 - val_accuracy: 0.6460
# Epoch 5/20
# 63/63 - 38s - loss: 0.5728 - accuracy: 0.7805 - val_loss: 0.7383 - val_accuracy: 0.7220
# Epoch 6/20
# 63/63 - 37s - loss: 0.5241 - accuracy: 0.7920 - val_loss: 0.7472 - val_accuracy: 0.7260
# Epoch 7/20
# 63/63 - 37s - loss: 0.4506 - accuracy: 0.8272 - val_loss: 0.7364 - val_accuracy: 0.7660
# Epoch 8/20
# 63/63 - 36s - loss: 0.4294 - accuracy: 0.8279 - val_loss: 0.8799 - val_accuracy: 0.7100
# Epoch 9/20
# 63/63 - 922s - loss: 0.4163 - accuracy: 0.8437 - val_loss: 0.7893 - val_accuracy: 0.7320
# 16/16 [==============================] - 2s 97ms/step - loss: 0.7364 - accuracy: 0.7660
# INFO:tensorflow:Assets written to: saved_models/Model 3/Run-3/assets
# --- Starting trial: run-4
# {'filter_size_1': 3, 'filters_number': 32, 'filter_size_2': 5, 'dense_size': 256}
# Epoch 1/20
# 63/63 - 873s - loss: 1.1859 - accuracy: 0.5050 - val_loss: 0.9977 - val_accuracy: 0.5840
# Epoch 2/20
# 63/63 - 47s - loss: 0.8530 - accuracy: 0.6431 - val_loss: 1.0133 - val_accuracy: 0.5740
# Epoch 3/20
# 63/63 - 49s - loss: 0.7518 - accuracy: 0.6913 - val_loss: 0.9280 - val_accuracy: 0.6300
# Epoch 4/20
# 63/63 - 50s - loss: 0.6837 - accuracy: 0.7248 - val_loss: 0.8001 - val_accuracy: 0.6700
# Epoch 5/20
# 63/63 - 51s - loss: 0.6111 - accuracy: 0.7542 - val_loss: 0.7748 - val_accuracy: 0.6980
# Epoch 6/20
# 63/63 - 52s - loss: 0.5536 - accuracy: 0.7740 - val_loss: 0.7210 - val_accuracy: 0.7080
# Epoch 7/20
# 63/63 - 55s - loss: 0.5506 - accuracy: 0.7895 - val_loss: 0.7919 - val_accuracy: 0.7380
# Epoch 8/20
# 63/63 - 54s - loss: 0.5191 - accuracy: 0.8014 - val_loss: 0.7321 - val_accuracy: 0.7360
# 16/16 [==============================] - 2s 89ms/step - loss: 0.7210 - accuracy: 0.7080
# INFO:tensorflow:Assets written to: saved_models/Model 3/Run-4/assets
# --- Starting trial: run-5
# {'filter_size_1': 3, 'filters_number': 32, 'filter_size_2': 5, 'dense_size': 512}
# Epoch 1/20
# 63/63 - 59s - loss: 1.1992 - accuracy: 0.5000 - val_loss: 1.0659 - val_accuracy: 0.5700
# Epoch 2/20
# 63/63 - 898s - loss: 0.8809 - accuracy: 0.6466 - val_loss: 0.9829 - val_accuracy: 0.6040
# Epoch 3/20
# 63/63 - 45s - loss: 0.7771 - accuracy: 0.6818 - val_loss: 0.9623 - val_accuracy: 0.6460
# Epoch 4/20
# 63/63 - 898s - loss: 0.6756 - accuracy: 0.7298 - val_loss: 0.8765 - val_accuracy: 0.6520
# Epoch 5/20
# 63/63 - 49s - loss: 0.6393 - accuracy: 0.7488 - val_loss: 0.7914 - val_accuracy: 0.6640
# Epoch 6/20
# 63/63 - 46s - loss: 0.5637 - accuracy: 0.7780 - val_loss: 0.7789 - val_accuracy: 0.7040
# Epoch 7/20
# 63/63 - 48s - loss: 0.5303 - accuracy: 0.7935 - val_loss: 0.7758 - val_accuracy: 0.7100
# Epoch 8/20
# 63/63 - 50s - loss: 0.4736 - accuracy: 0.8074 - val_loss: 0.7389 - val_accuracy: 0.7360
# Epoch 9/20
# 63/63 - 50s - loss: 0.4560 - accuracy: 0.8282 - val_loss: 0.7844 - val_accuracy: 0.7060
# Epoch 10/20
# 63/63 - 51s - loss: 0.4338 - accuracy: 0.8354 - val_loss: 0.8037 - val_accuracy: 0.7280
# 16/16 [==============================] - 2s 101ms/step - loss: 0.7389 - accuracy: 0.7360
# INFO:tensorflow:Assets written to: saved_models/Model 3/Run-5/assets
# --- Starting trial: run-6
# {'filter_size_1': 3, 'filters_number': 32, 'filter_size_2': 5, 'dense_size': 1024}
# Epoch 1/20
# 63/63 - 57s - loss: 1.4069 - accuracy: 0.4206 - val_loss: 1.1114 - val_accuracy: 0.5560
# Epoch 2/20
# 63/63 - 58s - loss: 0.9335 - accuracy: 0.6174 - val_loss: 0.9744 - val_accuracy: 0.5800
# Epoch 3/20
# 63/63 - 60s - loss: 0.8361 - accuracy: 0.6566 - val_loss: 0.8670 - val_accuracy: 0.6580
# Epoch 4/20
# 63/63 - 61s - loss: 0.7472 - accuracy: 0.6921 - val_loss: 0.8437 - val_accuracy: 0.6500
# Epoch 5/20
# 63/63 - 7250s - loss: 0.6728 - accuracy: 0.7320 - val_loss: 0.7424 - val_accuracy: 0.7120
# Epoch 6/20
# 63/63 - 3510s - loss: 0.6334 - accuracy: 0.7540 - val_loss: 0.7949 - val_accuracy: 0.6920

# %%
# Loading a model to evaluate on the test set
model = tf.keras.models.load_model(r"saved_models/Model 3/Run-1")

# %%
test_loss, test_accuracy = model.evaluate(images_test,labels_test)

# %%
# Printing the test results
print('Test loss: {0:.4f}. Test accuracy: {1:.2f}%'.format(test_loss, test_accuracy*100.))

# %%
# %load_ext tensorboard
# %tensorboard --logdir "Logs/Model 3/hparam_tuning"

# %%
# %load_ext tensorboard
# %tensorboard --logdir "Logs/Model 3/fit"
